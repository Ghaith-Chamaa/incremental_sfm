# %%
import cv2
import numpy as np
import pandas as pd
import bundle_adjustment as ba
import reconstruction as rec
import matching as matcher
import os
import glob

base_path = os.getcwd()

# %%
def get_images(base_path, dataset, img_format, use_n_imgs=-1):
    images = []
    images_paths = sorted(
        glob.glob(
            os.path.join(base_path, "datasets", dataset) + "/*." + img_format,
            recursive=True,
        )
    )
    if not use_n_imgs==-1 and use_n_imgs<=len(images_paths):
        images_paths=images_paths[:use_n_imgs]
        
    for images_path in images_paths:
        try:
            images.append(cv2.imread(images_path, cv2.IMREAD_GRAYSCALE))
        except:
            raise ValueError(
                f"Need to pass in valid imgset name! Tried to read {images_path}"
            )

    return images

# %%
n_imgs = 46  # 46 if imgset = 'templering', 49 if imgset = 'Viking'
imgset = "templeRing"
K = np.matrix("1520.40 0.00 302.32; 0.00 1525.90 246.87; 0.00 0.00 1.00")

# imgset = "dino"
# n_imgs = 46
# K = np.matrix(
#     "3310.400000 0.000000 316.730000; 0.000000 3325.500000 200.550000; 0.000000 0.000000 1.000000"
# )
images = get_images(base_path, imgset, "png", n_imgs)
assert len(images) == n_imgs

# %%
keypoints, descriptors = matcher.get_sift_features(images)
bf_matcher = cv2.BFMatcher(cv2.NORM_L1)
matches = matcher.find_matches(bf_matcher, keypoints, descriptors, 0.65)
print('num_matches before outlier removal:', matcher.num_matches(matches))
matcher.print_num_img_pairs(matches)

matches = matcher.remove_outliers(matches, keypoints)
print("After outlier removal:")
matcher.print_num_img_pairs(matches)
img_adjacency, list_of_img_pairs = matcher.create_img_adjacency_matrix(n_imgs, matches)
# Out:
# [ WARN:0@2.358] global shadow_sift.hpp:13 SIFT_create DEPRECATED: cv.xfeatures2d.SIFT_create() is deprecated due SIFT tranfer to the main repository. https://github.com/opencv/opencv/issues/16736
# num_matches before outlier removal: 49934
# Number of img pairs is 1011 out of possible 1035
# After outlier removal:
# Number of img pairs is 226 out of possible 1035

# %%
### This cell initializes the reconstruction
best_pair = rec.best_img_pair(img_adjacency, matches, keypoints, K, top_x_perc=0.2)
R0, t0, R1, t1, points3d_with_views = rec.initialize_reconstruction(keypoints, matches, K, best_pair[0], best_pair[1])

R_mats = {best_pair[0]: R0, best_pair[1]: R1}
t_vecs = {best_pair[0]: t0, best_pair[1]: t1}

resected_imgs = [best_pair[0], best_pair[1]]
unresected_imgs = [i for i in range(len(images)) if i not in resected_imgs] 
print('initial image pair:', resected_imgs)
avg_err = 0
# Out:
# Triangulating: 372 points.
# initial image pair: [23, 25]

# %%
### This cell grows and refines the reconstruction 
BA_chkpts = [3,4,5,6] + [int(6*(1.34**i)) for i in range(25)]
while len(unresected_imgs) > 0:
    resected_idx, unresected_idx, prepend = rec.next_img_pair_to_grow_reconstruction(n_imgs, best_pair, resected_imgs, unresected_imgs, img_adjacency)
    points3d_with_views, pts3d_for_pnp, pts2d_for_pnp, triangulation_status = rec.get_correspondences_for_pnp(resected_idx, unresected_idx, points3d_with_views, matches, keypoints)
    if len(pts3d_for_pnp) < 12:
        print(f"{len(pts3d_for_pnp)} is too few correspondences for pnp. Skipping imgs resected:{resected_idx} and unresected:{unresected_idx}")
        print(f"Currently resected imgs: {resected_imgs}, unresected: {unresected_imgs}")
        continue

    R_res = R_mats[resected_idx]
    t_res = t_vecs[resected_idx]
    print(f"Unresected image: {unresected_idx}, resected: {resected_idx}")
    R_new, t_new = rec.do_pnp(pts3d_for_pnp, pts2d_for_pnp, K)
    R_mats[unresected_idx] = R_new
    t_vecs[unresected_idx] = t_new
    if prepend: resected_imgs.insert(0, unresected_idx)
    else: resected_imgs.append(unresected_idx)
    unresected_imgs.remove(unresected_idx)
    pnp_errors, projpts, avg_err, perc_inliers = rec.test_reproj_pnp_points(pts3d_for_pnp, pts2d_for_pnp, R_new, t_new, K)
    print(f"Average error of reprojecting points used to resect image {unresected_idx} back onto it is: {avg_err}")
    print(f"Fraction of Pnp inliers: {perc_inliers} num pts used in Pnp: {len(pnp_errors)}")
    
    if resected_idx < unresected_idx:
        kpts1, kpts2, kpts1_idxs, kpts2_idxs = rec.get_aligned_kpts(resected_idx, unresected_idx, keypoints, matches, mask=triangulation_status)
        if np.sum(triangulation_status) > 0: #at least 1 point needs to be triangulated
            points3d_with_views, tri_errors, avg_tri_err_l, avg_tri_err_r = rec.triangulate_points_and_reproject(R_res, t_res, R_new, t_new, K, points3d_with_views, resected_idx, unresected_idx, kpts1, kpts2, kpts1_idxs, kpts2_idxs, reproject=True)
    else:
        kpts1, kpts2, kpts1_idxs, kpts2_idxs = rec.get_aligned_kpts(unresected_idx, resected_idx, keypoints, matches, mask=triangulation_status)
        if np.sum(triangulation_status) > 0: #at least 1 point needs to be triangulated
            points3d_with_views, tri_errors, avg_tri_err_l, avg_tri_err_r = rec.triangulate_points_and_reproject(R_new, t_new, R_res, t_res, K, points3d_with_views, unresected_idx, resected_idx, kpts1, kpts2, kpts1_idxs, kpts2_idxs, reproject=True)
    
    if 0.8 < perc_inliers < 0.95 or 5 < avg_tri_err_l < 10 or 5 < avg_tri_err_r < 10: 
        #If % of inlers from Pnp is too low or triangulation error on either image is too high, bundle adjust
        points3d_with_views, R_mats, t_vecs = ba.do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, keypoints, K, ftol=1e0)
        
    if len(resected_imgs) in BA_chkpts or len(unresected_imgs) == 0 or perc_inliers <= 0.8 or avg_tri_err_l >= 10 or avg_tri_err_r >= 10:
        #If % of inlers from Pnp is very low or triangulation error on either image is very high, bundle adjust with stricter tolerance
        points3d_with_views, R_mats, t_vecs = ba.do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, keypoints, K, ftol=1e-1)
    
    av = 0
    for im in resected_imgs:
        p3d, p2d, avg_error, errors = rec.get_reproj_errors(im, points3d_with_views, R_mats[im], t_vecs[im], K, keypoints, distCoeffs=np.array([]))
        print(f'Average reprojection error on image {im} is {avg_error} pixels')
        av += avg_error
    av = av/len(resected_imgs)
    print(f'Average reprojection error across all {len(resected_imgs)} resected images is {av} pixels')
# Out:
# Unresected image: 24, resected: 23
# rvec: [[-0.15227498]
#  [-0.00463762]
#  [ 0.01802589]]
#
# tvec: [[ 0.01969175]
#  [-0.52677383]
#  [ 0.04154978]]
# Average error of reprojecting points used to resect image 24 back onto it is: 0.13236054922174492
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 311
# Triangulating: 230 points.
# Average reprojection error for just-triangulated points on image 23 is: 0.06741888890888598 pixels.
# Average reprojection error for just-triangulated points on image 24 is: 0.06789456378644983 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.6610e+01                                    2.49e+04
#        1              3         4.0421e+01      6.19e+00       7.36e-01       3.98e+04
#        2              4         3.2396e+01      8.02e+00       3.00e-01       1.98e+04
#        3              5         3.2099e+01      2.97e-01       7.18e-01       3.22e+04
#        4              6         2.9548e+01      2.55e+00       2.20e-02       4.46e+02
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 4.6610e+01, final cost 2.9548e+01, first-order optimality 4.46e+02.
# Average reprojection error on image 24 is 0.05709421055206903 pixels
# Average reprojection error on image 23 is 0.06385281552005798 pixels
# Average reprojection error on image 25 is 0.07162819795604543 pixels
# Average reprojection error across all 3 resected images is 0.06419174134272415 pixels
# Unresected image: 26, resected: 25
# rvec: [[-0.42631981]
#  [-0.00617549]
#  [ 0.06175733]]
#
# tvec: [[ 0.03081707]
#  [-1.39542601]
#  [ 0.29285672]]
# Average error of reprojecting points used to resect image 26 back onto it is: 0.33981927182245464
# Fraction of Pnp inliers: 0.9883268482490273 num pts used in Pnp: 257
# Triangulating: 277 points.
# Average reprojection error for just-triangulated points on image 25 is: 7.558889123196265 pixels.
# Average reprojection error for just-triangulated points on image 26 is: 1.9071846704260664 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.3446e+04                                    2.15e+06
#        1              2         2.5533e+02      2.32e+04       2.45e+00       2.47e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 2.3446e+04, final cost 2.5533e+02, first-order optimality 2.47e+05.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.5533e+02                                    2.47e+05
#        1              2         1.5603e+02      9.93e+01       1.50e-01       1.05e+05
#        2              3         1.4196e+02      1.41e+01       1.27e-02       1.97e+02
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 2.5533e+02, final cost 1.4196e+02, first-order optimality 1.97e+02.
# Average reprojection error on image 24 is 0.0648892816677909 pixels
# Average reprojection error on image 23 is 0.08497769361613965 pixels
# Average reprojection error on image 25 is 0.09533670136457931 pixels
# Average reprojection error on image 26 is 0.09602635248388675 pixels
# Average reprojection error across all 4 resected images is 0.08530750728309916 pixels
# Unresected image: 22, resected: 23
# rvec: [[ 0.05526454]
#  [ 0.13636532]
#  [-0.00769315]]
#
# tvec: [[0.01049139]
#  [0.17161614]
#  [0.0061985 ]]
# Average error of reprojecting points used to resect image 22 back onto it is: 0.21064778085297697
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 487
# Triangulating: 204 points.
# Average reprojection error for just-triangulated points on image 22 is: 0.06316025689105416 pixels.
# Average reprojection error for just-triangulated points on image 23 is: 0.0629057441739144 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.2523e+02                                    2.97e+04
#        1              3         1.9809e+02      2.71e+01       2.20e-01       2.98e+04
#        2              4         1.8911e+02      8.98e+00       1.44e-01       2.51e+04
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 2.2523e+02, final cost 1.8911e+02, first-order optimality 2.51e+04.
# Average reprojection error on image 24 is 0.08236655319787363 pixels
# Average reprojection error on image 23 is 0.08251986937572238 pixels
# Average reprojection error on image 25 is 0.10400688409215375 pixels
# Average reprojection error on image 26 is 0.10226125205322506 pixels
# Average reprojection error on image 22 is 0.09694174530639799 pixels
# Average reprojection error across all 5 resected images is 0.09361926080507456 pixels
# Unresected image: 27, resected: 26
# rvec: [[-0.55776328]
#  [-0.00238046]
#  [ 0.0804763 ]]
#
# tvec: [[ 0.07838772]
#  [-1.8001428 ]
#  [ 0.51543916]]
# Average error of reprojecting points used to resect image 27 back onto it is: 0.2903086856809391
# Fraction of Pnp inliers: 0.9936507936507937 num pts used in Pnp: 315
# Triangulating: 171 points.
# Average reprojection error for just-triangulated points on image 26 is: 7.008665303537386 pixels.
# Average reprojection error for just-triangulated points on image 27 is: 7.224060589031315 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.7074e+04                                    7.33e+05
#        1              2         3.6812e+02      3.67e+04       7.42e-01       2.14e+04
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 3.7074e+04, final cost 3.6812e+02, first-order optimality 2.14e+04.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.6812e+02                                    2.14e+04
#        1              2         3.5192e+02      1.62e+01       6.16e-02       4.94e+03
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 3.6812e+02, final cost 3.5192e+02, first-order optimality 4.94e+03.
# Average reprojection error on image 24 is 0.08767341936986864 pixels
# Average reprojection error on image 23 is 0.08775451387296362 pixels
# Average reprojection error on image 25 is 0.123057318197694 pixels
# Average reprojection error on image 26 is 0.10137295730100145 pixels
# Average reprojection error on image 22 is 0.09479480025273941 pixels
# Average reprojection error on image 27 is 0.11645247813872384 pixels
# Average reprojection error across all 6 resected images is 0.10185091452216516 pixels
# Unresected image: 21, resected: 22
# rvec: [[-0.16349569]
#  [ 0.03966083]
#  [ 3.1046083 ]]
#
# tvec: [[0.02487002]
#  [0.35587903]
#  [0.01413423]]
# Average error of reprojecting points used to resect image 21 back onto it is: 0.8067699462122312
# Fraction of Pnp inliers: 0.9963031423290203 num pts used in Pnp: 541
# Triangulating: 155 points.
# Average reprojection error for just-triangulated points on image 21 is: 8.056462577333818 pixels.
# Average reprojection error for just-triangulated points on image 22 is: 8.232146014161687 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.5383e+04                                    1.13e+06
#        1              2         1.9913e+03      4.34e+04       2.15e+00       1.05e+06
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 4.5383e+04, final cost 1.9913e+03, first-order optimality 1.05e+06.
# Average reprojection error on image 24 is 0.1118914753774572 pixels
# Average reprojection error on image 23 is 0.12572343100597988 pixels
# Average reprojection error on image 25 is 0.12944669395654268 pixels
# Average reprojection error on image 26 is 0.10737188641679726 pixels
# Average reprojection error on image 22 is 0.20076930416585437 pixels
# Average reprojection error on image 27 is 0.11727100344240138 pixels
# Average reprojection error on image 21 is 1.1148145317764258 pixels
# Average reprojection error across all 7 resected images is 0.27246976087735125 pixels
# Unresected image: 28, resected: 27
# rvec: [[ 0.33317198]
#  [-1.1913145 ]
#  [ 2.94550514]]
#
# tvec: [[ 0.08397188]
#  [-2.14225008]
#  [ 0.76172488]]
# Average error of reprojecting points used to resect image 28 back onto it is: 0.5400361203605407
# Fraction of Pnp inliers: 0.99644128113879 num pts used in Pnp: 281
# Triangulating: 180 points.
# Average reprojection error for just-triangulated points on image 27 is: 1.9626630651370975 pixels.
# Average reprojection error for just-triangulated points on image 28 is: 1.1927715630701485 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.7579e+03                                    1.05e+06
#        1              2         1.1873e+03      2.57e+03       6.79e-01       6.20e+05
#        2              3         5.6926e+02      6.18e+02       2.52e-01       1.62e+04
#        3              4         5.6886e+02      4.02e-01       1.43e-02       1.36e+02
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 3.7579e+03, final cost 5.6886e+02, first-order optimality 1.36e+02.
# Average reprojection error on image 24 is 0.10201251354874577 pixels
# Average reprojection error on image 23 is 0.11371534186556348 pixels
# Average reprojection error on image 25 is 0.1435600158051818 pixels
# Average reprojection error on image 26 is 0.11706525959730163 pixels
# Average reprojection error on image 22 is 0.08669010927585531 pixels
# Average reprojection error on image 27 is 0.09518039942826319 pixels
# Average reprojection error on image 21 is 0.12781707405924655 pixels
# Average reprojection error on image 28 is 0.11689260337781335 pixels
# Average reprojection error across all 8 resected images is 0.11286666461974638 pixels
# Unresected image: 20, resected: 21
# rvec: [[ 0.4193487 ]
#  [-0.30511705]
#  [ 3.09419588]]
#
# tvec: [[0.02994407]
#  [0.84536868]
#  [0.10701357]]
# Average error of reprojecting points used to resect image 20 back onto it is: 0.36768124356720167
# Fraction of Pnp inliers: 0.9937106918238994 num pts used in Pnp: 477
# Triangulating: 148 points.
# Average reprojection error for just-triangulated points on image 20 is: 8.252778580012647 pixels.
# Average reprojection error for just-triangulated points on image 21 is: 19.22083782884278 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.4850e+04                                    2.71e+06
#        1              2         1.4587e+03      8.34e+04       3.49e+00       2.54e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 8.4850e+04, final cost 1.4587e+03, first-order optimality 2.54e+05.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.4587e+03                                    2.54e+05
#        1              2         7.3675e+02      7.22e+02       7.59e-01       2.48e+04
#        2              3         7.3504e+02      1.71e+00       1.29e-02       7.05e+01
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.4587e+03, final cost 7.3504e+02, first-order optimality 7.05e+01.
# Average reprojection error on image 24 is 0.11259809631618235 pixels
# Average reprojection error on image 23 is 0.1262549463347017 pixels
# Average reprojection error on image 25 is 0.1550600612760923 pixels
# Average reprojection error on image 26 is 0.11755805300228606 pixels
# Average reprojection error on image 22 is 0.10516123266076285 pixels
# Average reprojection error on image 27 is 0.0970455580462547 pixels
# Average reprojection error on image 21 is 0.09888355780696124 pixels
# Average reprojection error on image 28 is 0.11753541373582208 pixels
# Average reprojection error on image 20 is 0.1439019825961379 pixels
# Average reprojection error across all 9 resected images is 0.11933321130835568 pixels
# Unresected image: 29, resected: 28
# rvec: [[-1.96765136]
#  [ 2.23995169]
#  [-1.02303863]]
#
# tvec: [[ 0.14189736]
#  [-2.32091789]
#  [ 0.85915257]]
# Average error of reprojecting points used to resect image 29 back onto it is: 0.5625399873234125
# Fraction of Pnp inliers: 0.9965870307167235 num pts used in Pnp: 293
# Triangulating: 256 points.
# Average reprojection error for just-triangulated points on image 28 is: 5.565461473176866 pixels.
# Average reprojection error for just-triangulated points on image 29 is: 5.926085139264119 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.4739e+04                                    3.62e+05
#        1              2         8.6987e+02      3.39e+04       1.68e+00       5.73e+04
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 3.4739e+04, final cost 8.6987e+02, first-order optimality 5.73e+04.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.6987e+02                                    5.73e+04
#        1              2         8.0657e+02      6.33e+01       7.54e-02       4.90e+02
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 8.6987e+02, final cost 8.0657e+02, first-order optimality 4.90e+02.
# Average reprojection error on image 24 is 0.11325140197349631 pixels
# Average reprojection error on image 23 is 0.12637706676243077 pixels
# Average reprojection error on image 25 is 0.16296337554763446 pixels
# Average reprojection error on image 26 is 0.12395944341706822 pixels
# Average reprojection error on image 22 is 0.1058159052843976 pixels
# Average reprojection error on image 27 is 0.11069559792634856 pixels
# Average reprojection error on image 21 is 0.09936504427870824 pixels
# Average reprojection error on image 28 is 0.09625127715895618 pixels
# Average reprojection error on image 20 is 0.14387972733967194 pixels
# Average reprojection error on image 29 is 0.11646445974151257 pixels
# Average reprojection error across all 10 resected images is 0.1199023299430225 pixels
# Unresected image: 19, resected: 20
# rvec: [[0.12704143]
#  [0.79326828]
#  [3.00515951]]
#
# tvec: [[0.11354423]
#  [1.25174034]
#  [0.24975604]]
# Average error of reprojecting points used to resect image 19 back onto it is: 0.45032445848097435
# Fraction of Pnp inliers: 0.9977272727272727 num pts used in Pnp: 440
# Triangulating: 127 points.
# Average reprojection error for just-triangulated points on image 19 is: 2.7833957897371295 pixels.
# Average reprojection error for just-triangulated points on image 20 is: 3.3276831500317585 pixels.
# Average reprojection error on image 24 is 0.11325140197349631 pixels
# Average reprojection error on image 23 is 0.12637706676243077 pixels
# Average reprojection error on image 25 is 0.16296337554763446 pixels
# Average reprojection error on image 26 is 0.12395944341706822 pixels
# Average reprojection error on image 22 is 0.1058159052843976 pixels
# Average reprojection error on image 27 is 0.11069559792634856 pixels
# Average reprojection error on image 21 is 0.09936504427870824 pixels
# Average reprojection error on image 28 is 0.09625127715895618 pixels
# Average reprojection error on image 20 is 0.6830037735821988 pixels
# Average reprojection error on image 29 is 0.11646445974151257 pixels
# Average reprojection error on image 19 is 0.9692744724705659 pixels
# Average reprojection error across all 11 resected images is 0.24612925619484705 pixels
# Unresected image: 30, resected: 29
# rvec: [[-0.85079802]
#  [-0.01763646]
#  [ 0.12557751]]
#
# tvec: [[ 0.14966573]
#  [-2.61480027]
#  [ 1.18156713]]
# Average error of reprojecting points used to resect image 30 back onto it is: 0.7971837226253377
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 291
# Triangulating: 127 points.
# Average reprojection error for just-triangulated points on image 29 is: 0.8662239810030096 pixels.
# Average reprojection error for just-triangulated points on image 30 is: 0.4121968208774776 pixels.
# Average reprojection error on image 24 is 0.11325140197349631 pixels
# Average reprojection error on image 23 is 0.12637706676243077 pixels
# Average reprojection error on image 25 is 0.16296337554763446 pixels
# Average reprojection error on image 26 is 0.12395944341706822 pixels
# Average reprojection error on image 22 is 0.1058159052843976 pixels
# Average reprojection error on image 27 is 0.11069559792634856 pixels
# Average reprojection error on image 21 is 0.09936504427870824 pixels
# Average reprojection error on image 28 is 0.09625127715895618 pixels
# Average reprojection error on image 20 is 0.6830037735821988 pixels
# Average reprojection error on image 29 is 0.2573216479075039 pixels
# Average reprojection error on image 19 is 0.9692744724705659 pixels
# Average reprojection error on image 30 is 0.6802140180272914 pixels
# Average reprojection error across all 12 resected images is 0.29404108536138335 pixels
# Unresected image: 18, resected: 19
# rvec: [[0.34987701]
#  [0.55741493]
#  [3.0190269 ]]
#
# tvec: [[0.12217934]
#  [1.64747811]
#  [0.37925434]]
# Average error of reprojecting points used to resect image 18 back onto it is: 1.9766475742631846
# Fraction of Pnp inliers: 0.9612590799031477 num pts used in Pnp: 413
# Triangulating: 175 points.
# Average reprojection error for just-triangulated points on image 18 is: 0.6482686274264436 pixels.
# Average reprojection error for just-triangulated points on image 19 is: 0.6480052624180492 pixels.
# Average reprojection error on image 24 is 0.11325140197349631 pixels
# Average reprojection error on image 23 is 0.12637706676243077 pixels
# Average reprojection error on image 25 is 0.16296337554763446 pixels
# Average reprojection error on image 26 is 0.12395944341706822 pixels
# Average reprojection error on image 22 is 0.1058159052843976 pixels
# Average reprojection error on image 27 is 0.11069559792634856 pixels
# Average reprojection error on image 21 is 0.09936504427870824 pixels
# Average reprojection error on image 28 is 0.09625127715895618 pixels
# Average reprojection error on image 20 is 0.6830037735821988 pixels
# Average reprojection error on image 29 is 0.2573216479075039 pixels
# Average reprojection error on image 19 is 0.8934011772489863 pixels
# Average reprojection error on image 30 is 0.6802140180272914 pixels
# Average reprojection error on image 18 is 1.5819879630774472 pixels
# Average reprojection error across all 13 resected images is 0.387277514784036 pixels
# Unresected image: 31, resected: 30
# rvec: [[-1.00946981]
#  [ 0.847317  ]
#  [-2.73877657]]
#
# tvec: [[ 0.22713819]
#  [-2.87789387]
#  [ 1.54482248]]
# Average error of reprojecting points used to resect image 31 back onto it is: 0.9317865892161934
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 248
# Triangulating: 163 points.
# Average reprojection error for just-triangulated points on image 30 is: 0.2192076924030098 pixels.
# Average reprojection error for just-triangulated points on image 31 is: 0.22224217598087226 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.7527e+03                                    3.51e+05
#        1              2         4.0467e+03      4.71e+03       1.06e+00       1.23e+06
#        2              3         1.0609e+03      2.99e+03       1.34e-01       4.05e+04
#        3              4         1.0570e+03      3.92e+00       5.75e-02       2.17e+03
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 8.7527e+03, final cost 1.0570e+03, first-order optimality 2.17e+03.
# Average reprojection error on image 24 is 0.11961393143147872 pixels
# Average reprojection error on image 23 is 0.13854101894644139 pixels
# Average reprojection error on image 25 is 0.17157539640838373 pixels
# Average reprojection error on image 26 is 0.13301280902913473 pixels
# Average reprojection error on image 22 is 0.11669532899385437 pixels
# Average reprojection error on image 27 is 0.12712285138179605 pixels
# Average reprojection error on image 21 is 0.1141265425459031 pixels
# Average reprojection error on image 28 is 0.12256466152812234 pixels
# Average reprojection error on image 20 is 0.13164749349827745 pixels
# Average reprojection error on image 29 is 0.12028861491069667 pixels
# Average reprojection error on image 19 is 0.09967568769764455 pixels
# Average reprojection error on image 30 is 0.11490491592602564 pixels
# Average reprojection error on image 18 is 0.11676137156100824 pixels
# Average reprojection error on image 31 is 0.13629715403997855 pixels
# Average reprojection error across all 14 resected images is 0.1259162698499104 pixels
# Unresected image: 17, resected: 18
# rvec: [[ 0.15056462]
#  [-1.00672506]
#  [-3.1190319 ]]
#
# tvec: [[0.07360218]
#  [2.06206322]
#  [0.7045335 ]]
# Average error of reprojecting points used to resect image 17 back onto it is: 0.6973715344518818
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 350
# Triangulating: 138 points.
# Average reprojection error for just-triangulated points on image 17 is: 4.9484347475804125 pixels.
# Average reprojection error for just-triangulated points on image 18 is: 8.914814935978407 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.0910e+04                                    7.17e+05
#        1              2         1.5570e+03      1.94e+04       1.64e+00       4.52e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 2.0910e+04, final cost 1.5570e+03, first-order optimality 4.52e+05.
# Average reprojection error on image 24 is 0.13011430234629015 pixels
# Average reprojection error on image 23 is 0.14148880828295085 pixels
# Average reprojection error on image 25 is 0.1719025431631894 pixels
# Average reprojection error on image 26 is 0.13455911958227842 pixels
# Average reprojection error on image 22 is 0.12643876116204977 pixels
# Average reprojection error on image 27 is 0.12788397156765785 pixels
# Average reprojection error on image 21 is 0.1195310164799626 pixels
# Average reprojection error on image 28 is 0.1239684062568091 pixels
# Average reprojection error on image 20 is 0.13591183925622838 pixels
# Average reprojection error on image 29 is 0.12092258298433861 pixels
# Average reprojection error on image 19 is 0.11118933368487051 pixels
# Average reprojection error on image 30 is 0.11552221370726154 pixels
# Average reprojection error on image 18 is 0.24484357895055894 pixels
# Average reprojection error on image 31 is 0.13679788441871554 pixels
# Average reprojection error on image 17 is 0.6710691994544663 pixels
# Average reprojection error across all 15 resected images is 0.17414290408650854 pixels
# Unresected image: 32, resected: 31
# rvec: [[-1.11527666]
#  [-0.00687503]
#  [ 0.16341689]]
#
# tvec: [[ 0.29019213]
#  [-3.11726527]
#  [ 1.97383903]]
# Average error of reprojecting points used to resect image 32 back onto it is: 0.31607393872637146
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 235
# Triangulating: 196 points.
# Average reprojection error for just-triangulated points on image 31 is: 4.011973268688143 pixels.
# Average reprojection error for just-triangulated points on image 32 is: 0.947104847171544 pixels.
# Average reprojection error on image 24 is 0.13011430234629015 pixels
# Average reprojection error on image 23 is 0.14148880828295085 pixels
# Average reprojection error on image 25 is 0.1719025431631894 pixels
# Average reprojection error on image 26 is 0.13455911958227842 pixels
# Average reprojection error on image 22 is 0.12643876116204977 pixels
# Average reprojection error on image 27 is 0.12788397156765785 pixels
# Average reprojection error on image 21 is 0.1195310164799626 pixels
# Average reprojection error on image 28 is 0.1239684062568091 pixels
# Average reprojection error on image 20 is 0.13591183925622838 pixels
# Average reprojection error on image 29 is 0.12092258298433861 pixels
# Average reprojection error on image 19 is 0.11118933368487051 pixels
# Average reprojection error on image 30 is 0.11552221370726154 pixels
# Average reprojection error on image 18 is 0.24484357895055894 pixels
# Average reprojection error on image 31 is 1.3880901007561268 pixels
# Average reprojection error on image 17 is 0.6710691994544663 pixels
# Average reprojection error on image 32 is 0.603039270641103 pixels
# Average reprojection error across all 16 resected images is 0.2791546905172589 pixels
# Unresected image: 16, resected: 17
# rvec: [[ 0.7787695 ]
#  [ 0.01100394]
#  [-0.1264322 ]]
#
# tvec: [[0.16500394]
#  [2.40985131]
#  [1.01072879]]
# Average error of reprojecting points used to resect image 16 back onto it is: 0.3369926664085203
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 287
# Triangulating: 201 points.
# Average reprojection error for just-triangulated points on image 16 is: 3.9000617523851853 pixels.
# Average reprojection error for just-triangulated points on image 17 is: 4.254624541093228 pixels.
# Average reprojection error on image 24 is 0.13011430234629015 pixels
# Average reprojection error on image 23 is 0.14148880828295085 pixels
# Average reprojection error on image 25 is 0.1719025431631894 pixels
# Average reprojection error on image 26 is 0.13455911958227842 pixels
# Average reprojection error on image 22 is 0.12643876116204977 pixels
# Average reprojection error on image 27 is 0.12788397156765785 pixels
# Average reprojection error on image 21 is 0.1195310164799626 pixels
# Average reprojection error on image 28 is 0.1239684062568091 pixels
# Average reprojection error on image 20 is 0.13591183925622838 pixels
# Average reprojection error on image 29 is 0.12092258298433861 pixels
# Average reprojection error on image 19 is 0.11118933368487051 pixels
# Average reprojection error on image 30 is 0.11552221370726154 pixels
# Average reprojection error on image 18 is 0.24484357895055894 pixels
# Average reprojection error on image 31 is 1.3880901007561268 pixels
# Average reprojection error on image 17 is 1.7195329893662445 pixels
# Average reprojection error on image 32 is 0.603039270641103 pixels
# Average reprojection error on image 16 is 1.8107816313812928 pixels
# Average reprojection error across all 17 resected images is 0.43092473350407134 pixels
# Unresected image: 33, resected: 32
# rvec: [[ 0.49431841]
#  [-1.64973498]
#  [ 2.58675859]]
#
# tvec: [[ 0.3438165 ]
#  [-3.26997876]
#  [ 2.36543041]]
# Average error of reprojecting points used to resect image 33 back onto it is: 2.412629035466642
# Fraction of Pnp inliers: 0.98 num pts used in Pnp: 250
# Triangulating: 130 points.
# Average reprojection error for just-triangulated points on image 32 is: 0.2531448225729955 pixels.
# Average reprojection error for just-triangulated points on image 33 is: 0.2551782080533491 pixels.
# Average reprojection error on image 24 is 0.13011430234629015 pixels
# Average reprojection error on image 23 is 0.14148880828295085 pixels
# Average reprojection error on image 25 is 0.1719025431631894 pixels
# Average reprojection error on image 26 is 0.13455911958227842 pixels
# Average reprojection error on image 22 is 0.12643876116204977 pixels
# Average reprojection error on image 27 is 0.12788397156765785 pixels
# Average reprojection error on image 21 is 0.1195310164799626 pixels
# Average reprojection error on image 28 is 0.1239684062568091 pixels
# Average reprojection error on image 20 is 0.13591183925622838 pixels
# Average reprojection error on image 29 is 0.12092258298433861 pixels
# Average reprojection error on image 19 is 0.11118933368487051 pixels
# Average reprojection error on image 30 is 0.11552221370726154 pixels
# Average reprojection error on image 18 is 0.24484357895055894 pixels
# Average reprojection error on image 31 is 1.3880901007561268 pixels
# Average reprojection error on image 17 is 1.7195329893662445 pixels
# Average reprojection error on image 32 is 0.5219585607500974 pixels
# Average reprojection error on image 16 is 1.8107816313812928 pixels
# Average reprojection error on image 33 is 1.6745537524041998 pixels
# Average reprojection error across all 18 resected images is 0.4955107506712449 pixels
# Unresected image: 15, resected: 16
# rvec: [[ 0.80865901]
#  [-2.00194493]
#  [ 2.07443491]]
#
# tvec: [[0.13852715]
#  [2.70254403]
#  [1.37656136]]
# Average error of reprojecting points used to resect image 15 back onto it is: 2.125023296980386
# Fraction of Pnp inliers: 0.819078947368421 num pts used in Pnp: 304
# Triangulating: 178 points.
# Average reprojection error for just-triangulated points on image 15 is: 0.5819678594013769 pixels.
# Average reprojection error for just-triangulated points on image 16 is: 0.5944239056645823 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.4746e+04                                    9.01e+05
#        1              2         1.6316e+04      2.84e+04       2.21e+00       2.05e+06
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 4.4746e+04, final cost 1.6316e+04, first-order optimality 2.05e+06.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.6316e+04                                    2.05e+06
#        1              3         9.2924e+03      7.02e+03       5.48e-01       3.90e+05
#        2              5         7.6264e+03      1.67e+03       1.62e-01       1.40e+05
#        3              7         7.2588e+03      3.68e+02       7.61e-02       4.45e+04
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.6316e+04, final cost 7.2588e+03, first-order optimality 4.45e+04.
# Average reprojection error on image 24 is 0.12589446795488465 pixels
# Average reprojection error on image 23 is 0.14387455363109591 pixels
# Average reprojection error on image 25 is 0.18018473172202154 pixels
# Average reprojection error on image 26 is 0.1410354519710237 pixels
# Average reprojection error on image 22 is 0.12463780627155224 pixels
# Average reprojection error on image 27 is 0.13998015040507905 pixels
# Average reprojection error on image 21 is 0.1264481465304354 pixels
# Average reprojection error on image 28 is 0.142808477429639 pixels
# Average reprojection error on image 20 is 0.142784214212638 pixels
# Average reprojection error on image 29 is 0.20916494897601873 pixels
# Average reprojection error on image 19 is 0.1166509197685844 pixels
# Average reprojection error on image 30 is 0.186244531462535 pixels
# Average reprojection error on image 18 is 0.12208210451229128 pixels
# Average reprojection error on image 31 is 0.3181964417257168 pixels
# Average reprojection error on image 17 is 0.13668035951615445 pixels
# Average reprojection error on image 32 is 0.43472012661295323 pixels
# Average reprojection error on image 16 is 0.13134592546123966 pixels
# Average reprojection error on image 33 is 0.6105242459761143 pixels
# Average reprojection error on image 15 is 0.14050533797666415 pixels
# Average reprojection error across all 19 resected images is 0.1933559443219285 pixels
# Unresected image: 34, resected: 33
# rvec: [[-1.53001677]
#  [ 0.06336703]
#  [ 0.30189458]]
#
# tvec: [[ 0.43831766]
#  [-3.39507736]
#  [ 2.88995938]]
# Average error of reprojecting points used to resect image 34 back onto it is: 1.028092329015747
# Fraction of Pnp inliers: 0.9962264150943396 num pts used in Pnp: 265
# Triangulating: 139 points.
# Average reprojection error for just-triangulated points on image 33 is: 10.224667422045098 pixels.
# Average reprojection error for just-triangulated points on image 34 is: 2.8755825743717245 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.7071e+04                                    1.08e+06
#        1              3         1.3700e+04      1.34e+04       8.51e-01       4.81e+05
#        2              4         7.4047e+03      6.30e+03       1.04e+00       1.67e+05
#        3              6         7.0830e+03      3.22e+02       4.82e-01       1.01e+05
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 2.7071e+04, final cost 7.0830e+03, first-order optimality 1.01e+05.
# Average reprojection error on image 24 is 0.12640069412043145 pixels
# Average reprojection error on image 23 is 0.14409693443510346 pixels
# Average reprojection error on image 25 is 0.18315668243388328 pixels
# Average reprojection error on image 26 is 0.1440059631469574 pixels
# Average reprojection error on image 22 is 0.12433624551514014 pixels
# Average reprojection error on image 27 is 0.14710839306030474 pixels
# Average reprojection error on image 21 is 0.12494127429925073 pixels
# Average reprojection error on image 28 is 0.15465046784790992 pixels
# Average reprojection error on image 20 is 0.1397541142390084 pixels
# Average reprojection error on image 29 is 0.2366381511264489 pixels
# Average reprojection error on image 19 is 0.11449661512258369 pixels
# Average reprojection error on image 30 is 0.2161189801678643 pixels
# Average reprojection error on image 18 is 0.11605553559164497 pixels
# Average reprojection error on image 31 is 0.3331842005541914 pixels
# Average reprojection error on image 17 is 0.13187366617538765 pixels
# Average reprojection error on image 32 is 0.5036575447465437 pixels
# Average reprojection error on image 16 is 0.11076559386916886 pixels
# Average reprojection error on image 33 is 0.7235869172025903 pixels
# Average reprojection error on image 15 is 0.12356991873367237 pixels
# Average reprojection error on image 34 is 0.5414611841711442 pixels
# Average reprojection error across all 20 resected images is 0.22199295382796153 pixels
# Unresected image: 14, resected: 15
# rvec: [[ 1.12745168]
#  [-0.01346884]
#  [-0.16382265]]
#
# tvec: [[0.28900382]
#  [3.03063214]
#  [1.9468119 ]]
# Average error of reprojecting points used to resect image 14 back onto it is: 0.4562906111508111
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 191
# Triangulating: 83 points.
# Average reprojection error for just-triangulated points on image 14 is: 7.280332324833618 pixels.
# Average reprojection error for just-triangulated points on image 15 is: 8.929319043795337 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.0190e+04                                    6.43e+05
#        1              3         1.2888e+04      1.73e+04       5.83e-01       4.73e+05
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 3.0190e+04, final cost 1.2888e+04, first-order optimality 4.73e+05.
# Average reprojection error on image 24 is 0.12734795048200076 pixels
# Average reprojection error on image 23 is 0.144732736027597 pixels
# Average reprojection error on image 25 is 0.184238947327603 pixels
# Average reprojection error on image 26 is 0.14420398199263895 pixels
# Average reprojection error on image 22 is 0.12476354385204427 pixels
# Average reprojection error on image 27 is 0.14837353165055625 pixels
# Average reprojection error on image 21 is 0.1255124857830655 pixels
# Average reprojection error on image 28 is 0.15686485136825354 pixels
# Average reprojection error on image 20 is 0.1404642193857006 pixels
# Average reprojection error on image 29 is 0.24442504424250278 pixels
# Average reprojection error on image 19 is 0.11541538564360196 pixels
# Average reprojection error on image 30 is 0.22516370087890217 pixels
# Average reprojection error on image 18 is 0.11736789620280726 pixels
# Average reprojection error on image 31 is 0.34317197282510303 pixels
# Average reprojection error on image 17 is 0.13519444285352245 pixels
# Average reprojection error on image 32 is 0.5247117828658421 pixels
# Average reprojection error on image 16 is 0.11782765880198334 pixels
# Average reprojection error on image 33 is 0.6528525074616569 pixels
# Average reprojection error on image 15 is 1.6207568391782603 pixels
# Average reprojection error on image 34 is 0.5935471267605004 pixels
# Average reprojection error on image 14 is 2.5072223299109897 pixels
# Average reprojection error across all 21 resected images is 0.40448375883310156 pixels
# Unresected image: 35, resected: 34
# rvec: [[-1.57168745]
#  [ 0.03647754]
#  [ 0.2758576 ]]
#
# tvec: [[ 0.53012679]
#  [-3.41628257]
#  [ 3.43566445]]
# Average error of reprojecting points used to resect image 35 back onto it is: 1.2705471357090035
# Fraction of Pnp inliers: 0.9926739926739927 num pts used in Pnp: 273
# Triangulating: 131 points.
# Average reprojection error for just-triangulated points on image 34 is: 7.528898493821236 pixels.
# Average reprojection error for just-triangulated points on image 35 is: 0.43293791904235557 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.2674e+04                                    7.39e+05
#        1              2         1.1845e+04      1.08e+04       2.84e+00       6.81e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 2.2674e+04, final cost 1.1845e+04, first-order optimality 6.81e+05.
# Average reprojection error on image 24 is 0.15052450954546584 pixels
# Average reprojection error on image 23 is 0.1480288098439425 pixels
# Average reprojection error on image 25 is 0.19389198145004638 pixels
# Average reprojection error on image 26 is 0.15048113443115743 pixels
# Average reprojection error on image 22 is 0.12823923377041085 pixels
# Average reprojection error on image 27 is 0.15710674382462517 pixels
# Average reprojection error on image 21 is 0.12688539283827707 pixels
# Average reprojection error on image 28 is 0.17397320863095256 pixels
# Average reprojection error on image 20 is 0.14112621172029308 pixels
# Average reprojection error on image 29 is 0.28529501265639556 pixels
# Average reprojection error on image 19 is 0.11954466185666685 pixels
# Average reprojection error on image 30 is 0.26650041549614545 pixels
# Average reprojection error on image 18 is 0.11897736394223318 pixels
# Average reprojection error on image 31 is 0.40991963372584717 pixels
# Average reprojection error on image 17 is 0.14073391332595453 pixels
# Average reprojection error on image 32 is 0.7458717961584241 pixels
# Average reprojection error on image 16 is 0.12018928949899166 pixels
# Average reprojection error on image 33 is 0.6485358261391022 pixels
# Average reprojection error on image 15 is 0.12222730463168555 pixels
# Average reprojection error on image 34 is 1.2540683354726108 pixels
# Average reprojection error on image 14 is 0.17479187943260374 pixels
# Average reprojection error on image 35 is 2.0642406147217227 pixels
# Average reprojection error across all 22 resected images is 0.356416057868798 pixels
# Unresected image: 13, resected: 14
# rvec: [[0.01842143]
#  [1.7693393 ]
#  [2.38245538]]
#
# tvec: [[0.38380951]
#  [3.18987763]
#  [2.36072993]]
# Average error of reprojecting points used to resect image 13 back onto it is: 1.5415558573133064
# Fraction of Pnp inliers: 0.9933333333333333 num pts used in Pnp: 150
# Triangulating: 159 points.
# Average reprojection error for just-triangulated points on image 13 is: 0.6725959716374719 pixels.
# Average reprojection error for just-triangulated points on image 14 is: 0.914215702508191 pixels.
# Average reprojection error on image 24 is 0.15052450954546584 pixels
# Average reprojection error on image 23 is 0.1480288098439425 pixels
# Average reprojection error on image 25 is 0.19389198145004638 pixels
# Average reprojection error on image 26 is 0.15048113443115743 pixels
# Average reprojection error on image 22 is 0.12823923377041085 pixels
# Average reprojection error on image 27 is 0.15710674382462517 pixels
# Average reprojection error on image 21 is 0.12688539283827707 pixels
# Average reprojection error on image 28 is 0.17397320863095256 pixels
# Average reprojection error on image 20 is 0.14112621172029308 pixels
# Average reprojection error on image 29 is 0.28529501265639556 pixels
# Average reprojection error on image 19 is 0.11954466185666685 pixels
# Average reprojection error on image 30 is 0.26650041549614545 pixels
# Average reprojection error on image 18 is 0.11897736394223318 pixels
# Average reprojection error on image 31 is 0.40991963372584717 pixels
# Average reprojection error on image 17 is 0.14073391332595453 pixels
# Average reprojection error on image 32 is 0.7458717961584241 pixels
# Average reprojection error on image 16 is 0.12018928949899166 pixels
# Average reprojection error on image 33 is 0.6485358261391022 pixels
# Average reprojection error on image 15 is 0.12222730463168555 pixels
# Average reprojection error on image 34 is 1.2540683354726108 pixels
# Average reprojection error on image 14 is 0.44631240568899727 pixels
# Average reprojection error on image 35 is 2.0642406147217227 pixels
# Average reprojection error on image 13 is 1.074013971169005 pixels
# Average reprojection error across all 23 resected images is 0.39942120741473713 pixels
# Unresected image: 36, resected: 35
# rvec: [[-1.87316183]
#  [ 0.05908294]
#  [ 0.31686061]]
#
# tvec: [[ 0.57948915]
#  [-3.40519798]
#  [ 3.6142335 ]]
# Average error of reprojecting points used to resect image 36 back onto it is: 1.6349213189032956
# Fraction of Pnp inliers: 0.9307958477508651 num pts used in Pnp: 289
# Triangulating: 156 points.
# Average reprojection error for just-triangulated points on image 35 is: 12.06099817021025 pixels.
# Average reprojection error for just-triangulated points on image 36 is: 8.557061288315017 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.6517e+04                                    1.88e+06
#        1              2         1.3657e+04      4.29e+04       5.01e+00       6.07e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 5.6517e+04, final cost 1.3657e+04, first-order optimality 6.07e+05.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.3657e+04                                    6.07e+05
#        1              2         1.0721e+04      2.94e+03       5.69e-01       6.06e+05
#        2              3         7.2255e+03      3.50e+03       2.23e-01       6.99e+04
#        3              4         7.1975e+03      2.80e+01       5.92e-02       7.16e+03
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 1.3657e+04, final cost 7.1975e+03, first-order optimality 7.16e+03.
# Average reprojection error on image 24 is 0.12954845657333156 pixels
# Average reprojection error on image 23 is 0.14786017163112547 pixels
# Average reprojection error on image 25 is 0.19160411835570149 pixels
# Average reprojection error on image 26 is 0.14893995171036392 pixels
# Average reprojection error on image 22 is 0.12699242947631506 pixels
# Average reprojection error on image 27 is 0.15906074232734355 pixels
# Average reprojection error on image 21 is 0.12800503890617362 pixels
# Average reprojection error on image 28 is 0.1818510728538262 pixels
# Average reprojection error on image 20 is 0.1420762008033622 pixels
# Average reprojection error on image 29 is 0.30663721941702266 pixels
# Average reprojection error on image 19 is 0.11845597949506331 pixels
# Average reprojection error on image 30 is 0.2756840367488569 pixels
# Average reprojection error on image 18 is 0.12048107537680527 pixels
# Average reprojection error on image 31 is 0.3678607433197458 pixels
# Average reprojection error on image 17 is 0.1404041952122975 pixels
# Average reprojection error on image 32 is 0.6107401319230427 pixels
# Average reprojection error on image 16 is 0.12382834963237647 pixels
# Average reprojection error on image 33 is 0.6147712055769148 pixels
# Average reprojection error on image 15 is 0.1277281132216938 pixels
# Average reprojection error on image 34 is 0.2219519474593452 pixels
# Average reprojection error on image 14 is 0.12880560658739862 pixels
# Average reprojection error on image 35 is 0.17713491918071084 pixels
# Average reprojection error on image 13 is 0.13594766838907754 pixels
# Average reprojection error on image 36 is 0.27506232419303256 pixels
# Average reprojection error across all 24 resected images is 0.21255965409878863 pixels
# Unresected image: 12, resected: 13
# rvec: [[ 0.21784957]
#  [-1.56265169]
#  [ 2.60833688]]
#
# tvec: [[0.42477875]
#  [3.312168  ]
#  [2.81986681]]
# Average error of reprojecting points used to resect image 12 back onto it is: 0.3577144097033583
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 122
# Triangulating: 113 points.
# Average reprojection error for just-triangulated points on image 12 is: 2.0365469534137484 pixels.
# Average reprojection error for just-triangulated points on image 13 is: 15.262884181076904 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.1147e+04                                    1.24e+06
#        1              2         8.5047e+03      4.26e+04       6.02e+00       2.47e+05
#        2              3         7.2320e+03      1.27e+03       7.44e-01       5.15e+03
#        3              4         7.2313e+03      6.90e-01       2.70e-02       1.97e+02
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 5.1147e+04, final cost 7.2313e+03, first-order optimality 1.97e+02.
# Average reprojection error on image 24 is 0.12942313176452727 pixels
# Average reprojection error on image 23 is 0.14725382103048007 pixels
# Average reprojection error on image 25 is 0.19164905996410658 pixels
# Average reprojection error on image 26 is 0.14878818649395736 pixels
# Average reprojection error on image 22 is 0.1270468998271861 pixels
# Average reprojection error on image 27 is 0.15896644873905352 pixels
# Average reprojection error on image 21 is 0.1283577468501111 pixels
# Average reprojection error on image 28 is 0.1818942783513512 pixels
# Average reprojection error on image 20 is 0.14231210250939874 pixels
# Average reprojection error on image 29 is 0.3065726743422116 pixels
# Average reprojection error on image 19 is 0.1187974262534432 pixels
# Average reprojection error on image 30 is 0.27562983029300825 pixels
# Average reprojection error on image 18 is 0.12059309679188954 pixels
# Average reprojection error on image 31 is 0.36762596614157395 pixels
# Average reprojection error on image 17 is 0.1412414849331934 pixels
# Average reprojection error on image 32 is 0.6100009012963276 pixels
# Average reprojection error on image 16 is 0.12584842919421418 pixels
# Average reprojection error on image 33 is 0.6139672229333628 pixels
# Average reprojection error on image 15 is 0.13103026017666533 pixels
# Average reprojection error on image 34 is 0.22094129049277783 pixels
# Average reprojection error on image 14 is 0.1340117334075488 pixels
# Average reprojection error on image 35 is 0.17487424537091362 pixels
# Average reprojection error on image 13 is 0.1244766863614974 pixels
# Average reprojection error on image 36 is 0.2654828965843626 pixels
# Average reprojection error on image 12 is 0.13749479902049347 pixels
# Average reprojection error across all 25 resected images is 0.20897122476494626 pixels
# Unresected image: 37, resected: 36
# rvec: [[-1.78640166]
#  [ 0.03487369]
#  [ 0.2831552 ]]
#
# tvec: [[ 0.60202787]
#  [-3.3581806 ]
#  [ 4.09540724]]
# Average error of reprojecting points used to resect image 37 back onto it is: 0.7468968199274928
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 317
# Triangulating: 155 points.
# Average reprojection error for just-triangulated points on image 36 is: 13.034234702086748 pixels.
# Average reprojection error for just-triangulated points on image 37 is: 2.212676842609804 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.3745e+04                                    1.22e+06
#        1              3         1.4493e+04      2.93e+04       4.16e+00       4.82e+05
#        2              4         8.1089e+03      6.38e+03       3.77e+00       2.50e+05
#        3              6         7.5843e+03      5.25e+02       5.20e-01       6.26e+04
# ...
# Average reprojection error on image 44 is 0.4249799430791471 pixels
# Average reprojection error on image 4 is 0.380781529070534 pixels
# Average reprojection error on image 45 is 0.827460171732451 pixels
# Average reprojection error across all 42 resected images is 0.2529506757245005 pixels
# Unresected image: 3, resected: 4
# rvec: [[ 2.97331426]
#  [-0.01746456]
#  [-0.46520087]]
#
# tvec: [[0.88057524]
#  [0.38269667]
#  [6.77487002]]
# Average error of reprojecting points used to resect image 3 back onto it is: 1.2857850106916255
# Fraction of Pnp inliers: 0.9916317991631799 num pts used in Pnp: 239
# Triangulating: 149 points.
# Average reprojection error for just-triangulated points on image 3 is: 0.5151255673360904 pixels.
# Average reprojection error for just-triangulated points on image 4 is: 0.5074058480704141 pixels.
# Average reprojection error on image 24 is 0.12868527562005458 pixels
# Average reprojection error on image 23 is 0.14509223505769628 pixels
# Average reprojection error on image 25 is 0.1918142649326091 pixels
# Average reprojection error on image 26 is 0.14963895809325595 pixels
# Average reprojection error on image 22 is 0.12664374222369215 pixels
# Average reprojection error on image 27 is 0.16050704872882735 pixels
# Average reprojection error on image 21 is 0.12834676909210702 pixels
# Average reprojection error on image 28 is 0.18636645522260195 pixels
# Average reprojection error on image 20 is 0.14238399591347767 pixels
# Average reprojection error on image 29 is 0.31231740749762893 pixels
# Average reprojection error on image 19 is 0.11879126257559403 pixels
# Average reprojection error on image 30 is 0.27598252218017794 pixels
# Average reprojection error on image 18 is 0.12059617741778081 pixels
# Average reprojection error on image 31 is 0.3700887732339832 pixels
# Average reprojection error on image 17 is 0.14260410328688836 pixels
# Average reprojection error on image 32 is 0.604030941725799 pixels
# Average reprojection error on image 16 is 0.12687398213548368 pixels
# Average reprojection error on image 33 is 0.6342633596737384 pixels
# Average reprojection error on image 15 is 0.13442676388204775 pixels
# Average reprojection error on image 34 is 0.23576504835366216 pixels
# Average reprojection error on image 14 is 0.14710682942391257 pixels
# Average reprojection error on image 35 is 0.18332198821302736 pixels
# Average reprojection error on image 13 is 0.1476112010606379 pixels
# Average reprojection error on image 36 is 0.18617259581237391 pixels
# Average reprojection error on image 12 is 0.1414886881271626 pixels
# Average reprojection error on image 37 is 0.18944249332418323 pixels
# Average reprojection error on image 11 is 0.12016308925205195 pixels
# Average reprojection error on image 38 is 0.1875588476818679 pixels
# Average reprojection error on image 10 is 0.15674951177727853 pixels
# Average reprojection error on image 39 is 0.17456581887311234 pixels
# Average reprojection error on image 9 is 0.13554746654979977 pixels
# Average reprojection error on image 40 is 0.16100358971576056 pixels
# Average reprojection error on image 8 is 0.10772079811010123 pixels
# Average reprojection error on image 41 is 0.16145862897145125 pixels
# Average reprojection error on image 7 is 0.10211862898945681 pixels
# Average reprojection error on image 42 is 0.14782063969525544 pixels
# Average reprojection error on image 6 is 0.15450523922131632 pixels
# Average reprojection error on image 43 is 0.7441224789590183 pixels
# Average reprojection error on image 5 is 1.2070091159420158 pixels
# Average reprojection error on image 44 is 0.4249799430791471 pixels
# Average reprojection error on image 4 is 0.4159156511021581 pixels
# Average reprojection error on image 45 is 0.827460171732451 pixels
# Average reprojection error on image 3 is 0.9904029815148975 pixels
# Average reprojection error across all 43 resected images is 0.2709178019529196 pixels
# Unresected image: 0, resected: 45
# rvec: [[-2.86941373]
#  [ 0.00582835]
#  [ 0.44995026]]
#
# tvec: [[ 0.96880598]
#  [-0.85343215]
#  [ 6.68173653]]
# Average error of reprojecting points used to resect image 0 back onto it is: 1.7968372124037901
# Fraction of Pnp inliers: 0.8935185185185185 num pts used in Pnp: 216
# Triangulating: 95 points.
# Average reprojection error for just-triangulated points on image 0 is: 0.24922500828244074 pixels.
# Average reprojection error for just-triangulated points on image 45 is: 0.24434336124767683 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.3732e+04                                    4.47e+05
#        1              2         9.2155e+03      4.52e+03       1.54e+00       4.19e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 1.3732e+04, final cost 9.2155e+03, first-order optimality 4.19e+05.
# Average reprojection error on image 24 is 0.12859192325632252 pixels
# Average reprojection error on image 23 is 0.14452535393113597 pixels
# Average reprojection error on image 25 is 0.19220158161792875 pixels
# Average reprojection error on image 26 is 0.14998392001396182 pixels
# Average reprojection error on image 22 is 0.12654379944753202 pixels
# Average reprojection error on image 27 is 0.16095251454950732 pixels
# Average reprojection error on image 21 is 0.12820386634020725 pixels
# Average reprojection error on image 28 is 0.18697747181887509 pixels
# Average reprojection error on image 20 is 0.14232274293099412 pixels
# Average reprojection error on image 29 is 0.3131382605608246 pixels
# Average reprojection error on image 19 is 0.11875540759292255 pixels
# Average reprojection error on image 30 is 0.2768507012582268 pixels
# Average reprojection error on image 18 is 0.1205921230226625 pixels
# Average reprojection error on image 31 is 0.3702788494470697 pixels
# Average reprojection error on image 17 is 0.14253451735426267 pixels
# Average reprojection error on image 32 is 0.6043901684369646 pixels
# Average reprojection error on image 16 is 0.1267417062596614 pixels
# Average reprojection error on image 33 is 0.6354209829937693 pixels
# Average reprojection error on image 15 is 0.13465173451358078 pixels
# Average reprojection error on image 34 is 0.23524155104382433 pixels
# Average reprojection error on image 14 is 0.14724990081779266 pixels
# Average reprojection error on image 35 is 0.1828068291770436 pixels
# Average reprojection error on image 13 is 0.14793111202069742 pixels
# Average reprojection error on image 36 is 0.1810728848670054 pixels
# Average reprojection error on image 12 is 0.1415024315571375 pixels
# Average reprojection error on image 37 is 0.17952880224665188 pixels
# Average reprojection error on image 11 is 0.12017098589304753 pixels
# Average reprojection error on image 38 is 0.18258711859557583 pixels
# Average reprojection error on image 10 is 0.1558404156942789 pixels
# Average reprojection error on image 39 is 0.17730821426816307 pixels
# Average reprojection error on image 9 is 0.1352141740112291 pixels
# Average reprojection error on image 40 is 0.17186663884047432 pixels
# Average reprojection error on image 8 is 0.10657441043054672 pixels
# Average reprojection error on image 41 is 0.18109281946008274 pixels
# Average reprojection error on image 7 is 0.09844091149815754 pixels
# Average reprojection error on image 42 is 0.15692741973368637 pixels
# Average reprojection error on image 6 is 0.12565581276720592 pixels
# Average reprojection error on image 43 is 0.20680865916540775 pixels
# Average reprojection error on image 5 is 0.1428563315223821 pixels
# Average reprojection error on image 44 is 0.19039566618473597 pixels
# Average reprojection error on image 4 is 0.23280164130855174 pixels
# Average reprojection error on image 45 is 0.20979301102072884 pixels
# Average reprojection error on image 3 is 0.1405265776402176 pixels
# Average reprojection error on image 0 is 1.3570748997413808 pixels
# Average reprojection error across all 44 resected images is 0.21615742829210036 pixels
# Unresected image: 2, resected: 3
# rvec: [[-3.10535622]
#  [ 0.03361655]
#  [ 0.42495952]]
#
# tvec: [[ 0.87076386]
#  [-0.07327983]
#  [ 6.84217585]]
# Average error of reprojecting points used to resect image 2 back onto it is: 0.6944121615197051
# Fraction of Pnp inliers: 0.9913419913419913 num pts used in Pnp: 231
# Triangulating: 140 points.
# Average reprojection error for just-triangulated points on image 2 is: 0.9233450402396112 pixels.
# Average reprojection error for just-triangulated points on image 3 is: 1.7689171871401859 pixels.
# Average reprojection error on image 24 is 0.12859192325632252 pixels
# Average reprojection error on image 23 is 0.14452535393113597 pixels
# Average reprojection error on image 25 is 0.19220158161792875 pixels
# Average reprojection error on image 26 is 0.14998392001396182 pixels
# Average reprojection error on image 22 is 0.12654379944753202 pixels
# Average reprojection error on image 27 is 0.16095251454950732 pixels
# Average reprojection error on image 21 is 0.12820386634020725 pixels
# Average reprojection error on image 28 is 0.18697747181887509 pixels
# Average reprojection error on image 20 is 0.14232274293099412 pixels
# Average reprojection error on image 29 is 0.3131382605608246 pixels
# Average reprojection error on image 19 is 0.11875540759292255 pixels
# Average reprojection error on image 30 is 0.2768507012582268 pixels
# Average reprojection error on image 18 is 0.1205921230226625 pixels
# Average reprojection error on image 31 is 0.3702788494470697 pixels
# Average reprojection error on image 17 is 0.14253451735426267 pixels
# Average reprojection error on image 32 is 0.6043901684369646 pixels
# Average reprojection error on image 16 is 0.1267417062596614 pixels
# Average reprojection error on image 33 is 0.6354209829937693 pixels
# Average reprojection error on image 15 is 0.13465173451358078 pixels
# Average reprojection error on image 34 is 0.23524155104382433 pixels
# Average reprojection error on image 14 is 0.14724990081779266 pixels
# Average reprojection error on image 35 is 0.1828068291770436 pixels
# Average reprojection error on image 13 is 0.14793111202069742 pixels
# Average reprojection error on image 36 is 0.1810728848670054 pixels
# Average reprojection error on image 12 is 0.1415024315571375 pixels
# Average reprojection error on image 37 is 0.17952880224665188 pixels
# Average reprojection error on image 11 is 0.12017098589304753 pixels
# Average reprojection error on image 38 is 0.18258711859557583 pixels
# Average reprojection error on image 10 is 0.1558404156942789 pixels
# Average reprojection error on image 39 is 0.17730821426816307 pixels
# Average reprojection error on image 9 is 0.1352141740112291 pixels
# Average reprojection error on image 40 is 0.17186663884047432 pixels
# Average reprojection error on image 8 is 0.10657441043054672 pixels
# Average reprojection error on image 41 is 0.18109281946008274 pixels
# Average reprojection error on image 7 is 0.09844091149815754 pixels
# Average reprojection error on image 42 is 0.15692741973368637 pixels
# Average reprojection error on image 6 is 0.12565581276720592 pixels
# Average reprojection error on image 43 is 0.20680865916540775 pixels
# Average reprojection error on image 5 is 0.1428563315223821 pixels
# Average reprojection error on image 44 is 0.19039566618473597 pixels
# Average reprojection error on image 4 is 0.23280164130855174 pixels
# Average reprojection error on image 45 is 0.20979301102072884 pixels
# Average reprojection error on image 3 is 0.5731161133707594 pixels
# Average reprojection error on image 0 is 1.3570748997413808 pixels
# Average reprojection error on image 2 is 0.6485441162123071 pixels
# Average reprojection error across all 45 resected images is 0.23537912215100584 pixels
# Unresected image: 1, resected: 0
# rvec: [[-2.99341613]
#  [ 0.01567376]
#  [ 0.44027435]]
#
# tvec: [[ 0.98109262]
#  [-0.40298646]
#  [ 6.80835558]]
# Average error of reprojecting points used to resect image 1 back onto it is: 0.5072222307788236
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 226
# Triangulating: 215 points.
# Average reprojection error for just-triangulated points on image 0 is: 10.426603234994742 pixels.
# Average reprojection error for just-triangulated points on image 1 is: 1.1221777605935903 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.7530e+04                                    1.51e+06
#        1              2         1.0839e+04      4.67e+04       1.02e+01       5.19e+05
#        2              3         8.6035e+03      2.24e+03       5.76e-01       3.65e+04
#        3              4         8.5934e+03      1.01e+01       8.13e-02       2.38e+04
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 5.7530e+04, final cost 8.5934e+03, first-order optimality 2.38e+04.
# Average reprojection error on image 24 is 0.12790551807366385 pixels
# Average reprojection error on image 23 is 0.14276406170477113 pixels
# Average reprojection error on image 25 is 0.19245836196229982 pixels
# Average reprojection error on image 26 is 0.14981372669528567 pixels
# Average reprojection error on image 22 is 0.12620265243617307 pixels
# Average reprojection error on image 27 is 0.1609214878534787 pixels
# Average reprojection error on image 21 is 0.12811632799647318 pixels
# Average reprojection error on image 28 is 0.1870833208961597 pixels
# Average reprojection error on image 20 is 0.14224221851877827 pixels
# Average reprojection error on image 29 is 0.31283277114715796 pixels
# Average reprojection error on image 19 is 0.11878987401087396 pixels
# Average reprojection error on image 30 is 0.2773666556084919 pixels
# Average reprojection error on image 18 is 0.12043284987133454 pixels
# Average reprojection error on image 31 is 0.37108962487111663 pixels
# Average reprojection error on image 17 is 0.14244395255123452 pixels
# Average reprojection error on image 32 is 0.6053118343386947 pixels
# Average reprojection error on image 16 is 0.1268404484315723 pixels
# Average reprojection error on image 33 is 0.6349880329370491 pixels
# Average reprojection error on image 15 is 0.13465757567083456 pixels
# Average reprojection error on image 34 is 0.2351888826922877 pixels
# Average reprojection error on image 14 is 0.14727738267815849 pixels
# Average reprojection error on image 35 is 0.18246937157475338 pixels
# Average reprojection error on image 13 is 0.14793380712501608 pixels
# Average reprojection error on image 36 is 0.17851422532487587 pixels
# Average reprojection error on image 12 is 0.14163004011828376 pixels
# Average reprojection error on image 37 is 0.17298192605561183 pixels
# Average reprojection error on image 11 is 0.12023976372550774 pixels
# Average reprojection error on image 38 is 0.17728011770628085 pixels
# Average reprojection error on image 10 is 0.15582248515948335 pixels
# Average reprojection error on image 39 is 0.17317887000278093 pixels
# Average reprojection error on image 9 is 0.13554948534877356 pixels
# Average reprojection error on image 40 is 0.16917975029719584 pixels
# Average reprojection error on image 8 is 0.10694415294637638 pixels
# Average reprojection error on image 41 is 0.17487034194113632 pixels
# Average reprojection error on image 7 is 0.09834476611393153 pixels
# Average reprojection error on image 42 is 0.15633626709585463 pixels
# Average reprojection error on image 6 is 0.12595759184462596 pixels
# Average reprojection error on image 43 is 0.15267828913124343 pixels
# Average reprojection error on image 5 is 0.14381653765419658 pixels
# Average reprojection error on image 44 is 0.16142025454666903 pixels
# Average reprojection error on image 4 is 0.10995306244522401 pixels
# Average reprojection error on image 45 is 0.12745429420494303 pixels
# Average reprojection error on image 3 is 0.11191664575842451 pixels
# Average reprojection error on image 0 is 0.0996804200278863 pixels
# Average reprojection error on image 2 is 0.16857578664861517 pixels
# Average reprojection error on image 1 is 0.11993636862981724 pixels
# Average reprojection error across all 46 resected images is 0.1782041778776825 pixels

# %%
### This cell visualizes the pointcloud
num_voxels = 200 #Set to 100 for faster visualization, 200 for higher resolution.
x, y, z = [], [], []
for pt3 in points3d_with_views:
    if abs(pt3.point3d[0][0]) + abs(pt3.point3d[0][1]) + abs(pt3.point3d[0][2]) < 100:
        x.append(pt3.point3d[0][0])
        y.append(pt3.point3d[0][1])
        z.append(pt3.point3d[0][2])
vpoints = list(zip(x,y,z))
vpoints = np.array(vpoints)
vpoints_df = pd.DataFrame(data=vpoints, index=[f"{i}" for i in range(vpoints.shape[0])], columns=["x", "y","z"])
# cloud = pyntcloud.PyntCloud(vpoints_df)
# cloud.add_structure('voxelgrid', n_x=num_voxels,n_y=num_voxels,n_z=num_voxels)
# cloud.structures[f'V([{num_voxels}, {num_voxels}, {num_voxels}],[None, None, None],True)'].plot(d=3)

# %%
import open3d as o3d
def visualize_sfm_open3d(points_3d):
    """
    Visualizes a 3D point cloud obtained from Structure from Motion (SfM) using Open3D.

    Parameters:
    points_3d (numpy.ndarray): A 2D NumPy array representing the 3D points. Each row contains the (x, y, z) coordinates of a point.

    Returns:
    None. The function displays the 3D point cloud in a new window using Open3D.
    """
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(points_3d)
    o3d.visualization.draw_geometries([pcd], window_name="SfM 3D Reconstruction")
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
visualize_sfm_open3d(vpoints)
